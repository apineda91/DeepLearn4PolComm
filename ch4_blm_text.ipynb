# %%
from __future__ import print_function
import tensorflow as tf
import numpy as np
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

from tensorflow.keras.optimizers import RMSprop

from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
import nltk
from nltk.corpus import stopwords
import string
import pandas as pd

import os
import sys
from keras.preprocessing.text import Tokenizer

from tensorflow.keras.preprocessing.sequence import pad_sequences
import keras.utils as ku
import keras.layers as kl
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D, Concatenate
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.models import Model
from keras.initializers import Constant
from tensorflow.keras.preprocessing.sequence import pad_sequences


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model

#from keras.models import Sequential
from tensorflow.keras.layers import Embedding, Activation, Dense, LSTM, Conv2D, Reshape, dot, Lambda, Dropout, MaxPooling2D
from keras.optimizers import SGD
from itertools import islice
from tensorflow.keras.layers import Flatten
from keras.models import model_from_json
from keras_preprocessing.image import ImageDataGenerator
from keras_preprocessing.sequence import TimeseriesGenerator


from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import math
import random
from keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, EarlyStopping
from datetime import *
from tensorflow.keras import optimizers
from keras.backend import int_shape
pd.set_option('display.max_colwidth',25)
from keras import backend as K
#from tensorflow.keras.layers import concatenate
#K.clear_session()

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

import pathlib
rando_seed = 1234
np.random.seed(rando_seed)
#os.chdir('/media/alex/easystore/ids_monthly/BLM_images/2014_11_12')
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
# Out:
# 2022-11-28 23:42:21.271436: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2022-11-28 23:42:21.271464: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#Evaluation of Model - Confusion Matrix Plot
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
cols = ['tweet_id', 'date', 'text', 'support', 'hashtags', 'users', 'urls', 'media_urls', 'nfollowers', 'nfriends', 'file_name', 'path']

DATA = pd.read_csv('blm_apsa_sample3.csv', names = cols, dtype = {'tweet_id':str, 'text':str, 'support':str, 'path':str, 'file_name':str})
DATA.head()
# Out:
#              tweet_id                      date                      text  \
# 0  534514976191303680  Tue Nov 18 01:14:35 +...  Missouri Gov Declares...
# 1  535629606855143424  Fri Nov 21 03:03:44 +...  #Ferguson Lively prot...
# 2  533637761258250242  Sat Nov 15 15:08:51 +...  School board fires Te...
# 3  535611054089187329  Fri Nov 21 01:50:01 +...  This campaign was fun...
# 4  534532177803747328  Tue Nov 18 02:22:56 +...  WOW afraid of your fr...
#
#   support  hashtags  users  urls                media_urls  nfollowers  \
# 0       2       NaN    NaN   NaN  http://pbs.twimg.com/...          85
# 1       1       NaN    NaN   NaN  http://pbs.twimg.com/...         576
# 2       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2594
# 3       1       NaN    NaN   NaN  http://pbs.twimg.com/...        6599
# 4       1       NaN    NaN   NaN  http://pbs.twimg.com/...        3074
#
#    nfriends            file_name                      path
# 0        20  B2r6ieiCQAAsrER.jpg  /media/alex/easystore...
# 1       528  B27wSReCMAA-MeD.jpg  /media/alex/easystore...
# 2      4126  B2fctmeCUAEiFZE.jpg  /media/alex/easystore...
# 3       580  B27fajnCUAERtfW.jpg  /media/alex/easystore...
# 4      2627  B2sKLtcCIAAkbYR.png  /media/alex/easystore...

# %%
DATA.dtypes
# Out:
# tweet_id       object
# date           object
# text           object
# support        object
# hashtags      float64
# users         float64
# urls          float64
# media_urls     object
# nfollowers      int64
# nfriends        int64
# file_name      object
# path           object
# dtype: object

# %%
conditions = [
    (DATA['support'] == '0'),
    (DATA['support'] != '0')
]

values = ['0', '1']

DATA['support2'] = np.select(conditions, values)

DATA.head(50)
# Out:
#               tweet_id                      date                      text  \
# 0   534514976191303680  Tue Nov 18 01:14:35 +...  Missouri Gov Declares...
# 1   535629606855143424  Fri Nov 21 03:03:44 +...  #Ferguson Lively prot...
# 2   533637761258250242  Sat Nov 15 15:08:51 +...  School board fires Te...
# 3   535611054089187329  Fri Nov 21 01:50:01 +...  This campaign was fun...
# 4   534532177803747328  Tue Nov 18 02:22:56 +...  WOW afraid of your fr...
# 5   532701599094026242  Thu Nov 13 01:08:53 +...  #shaunking IS the def...
# 6   532561172923682817  Wed Nov 12 15:50:52 +...  @TODAYshow: "We've go...
# 7   536574685988012033  Sun Nov 23 17:39:08 +...  "Prayer and protest a...
# 8   535592316040273920  Fri Nov 21 00:35:33 +...  Local authorities fin...
# 9   535196685996425217  Wed Nov 19 22:23:28 +...  #BREAKING Rallies Bei...
# 10  536600048935899136  Sun Nov 23 19:19:55 +...  @ITALIAN_404 Make thi...
# 11  529969316369022977  Wed Nov 05 12:11:46 +...  Remember Remember the...
# 12  536007323492163585  Sat Nov 22 04:04:39 +...  #Obama urges #Ferguso...
# 13  535147120006012928  Wed Nov 19 19:06:30 +...  "Violence will not be...
# 14  531137231994753024  Sat Nov 08 17:32:38 +...  Hip-hop artist Tef Po...
# 15  535587177619816448  Fri Nov 21 00:15:08 +...  Michael Brown Sr. To ...
# 16  532735141979095040  Thu Nov 13 03:22:10 +...  #ViolenceWillNotBeTol...
# 17  534415626576871424  Mon Nov 17 18:39:48 +...  Hands up! #ferguson #...
# 18  536368113768357888  Sun Nov 23 03:58:18 +...  this brings a tear to...
# 19  530460651404394496  Thu Nov 06 20:44:09 +...  People shouldn’t be a...
# 20  534462391644602368  Mon Nov 17 21:45:38 +...  #Ferguson water park ...
# 21  534790275592642560  Tue Nov 18 19:28:32 +...  #shaunking IS the def...
# 22  536414095591751680  Sun Nov 23 07:01:01 +...  BREAKING #FERGUSON #M...
# 23  528680502640009216  Sat Nov 01 22:50:28 +...  “@LynneMcCarthy: When...
# 24  536283054294450176  Sat Nov 22 22:20:18 +...  The Ferguson cop who ...
# 25  530935617879027712  Sat Nov 08 04:11:30 +...  Eric Harris &amp; Dyl...
# 26  532242289364836352  Tue Nov 11 18:43:45 +...  Great panel next week...
# 27  535579251588595712  Thu Nov 20 23:43:38 +...  An illegal chokehold ...
# 28  532392466281140224  Wed Nov 12 04:40:29 +...  #Ferguson protesters ...
# 29  535255712633720833  Thu Nov 20 02:18:01 +...  This 20yo is the youn...
# 30  534555296853544960  Tue Nov 18 03:54:48 +...  Remind me.., who R th...
# 31  530477744443105280  Thu Nov 06 21:52:04 +...  My #Palestinian siste...
# 32  528412404187934721  Sat Nov 01 05:05:09 +...  Kajieme Powell. We re...
# 33  536281100898021377  Sat Nov 22 22:12:32 +...  @alexiszotos: so does...
# 34  529422204199763968  Mon Nov 03 23:57:44 +...  If you don't know you...
# 35  534858438736879617  Tue Nov 18 23:59:23 +...  Lets show #Nixonland ...
# 36  535907091823620096  Fri Nov 21 21:26:22 +...  JUST IN; STL MAYOR: "...
# 37  533844141005078528  Sun Nov 16 04:48:56 +...  To the #Ferguson prot...
# 38  532727252409393152  Thu Nov 13 02:50:49 +...  UU's marching in #Fer...
# 39  535493392080187392  Thu Nov 20 18:02:28 +...  TBT: the #Ferguson Ch...
# 40  535065947825258496  Wed Nov 19 13:43:57 +...  We who believe in fre...
# 41  530899105149497344  Sat Nov 08 01:46:24 +...  BREAKING: New images ...
# 42  536325604975857665  Sun Nov 23 01:09:23 +...  Well... #OpFerguson #...
# 43  532321312576782336  Tue Nov 11 23:57:45 +...  Michael Brown's paren...
# 44  536085385269764096  Sat Nov 22 09:14:50 +...  Cop who killed mike B...
# 45  536577863026499586  Sun Nov 23 17:51:46 +...  At the MLK memorial. ...
# 46  536350957656113152  Sun Nov 23 02:50:07 +...  RT: Police Are Paid 2...
# 47  536586954394312704  Sun Nov 23 18:27:53 +...  Crowd outside Michael...
# 48  534336162023079936  Mon Nov 17 13:24:03 +...  MT "@NaughtyBeyotch: ...
# 49  534479647883272192  Mon Nov 17 22:54:12 +...  #Ferguson protesters ...
#
#    support  hashtags  users  urls                media_urls  nfollowers  \
# 0        2       NaN    NaN   NaN  http://pbs.twimg.com/...          85
# 1        1       NaN    NaN   NaN  http://pbs.twimg.com/...         576
# 2        1       NaN    NaN   NaN  http://pbs.twimg.com/...        2594
# 3        1       NaN    NaN   NaN  http://pbs.twimg.com/...        6599
# 4        1       NaN    NaN   NaN  http://pbs.twimg.com/...        3074
# 5        0       NaN    NaN   NaN  http://pbs.twimg.com/...       79180
# 6        2       NaN    NaN   NaN  http://pbs.twimg.com/...        1741
# 7        1       NaN    NaN   NaN  http://pbs.twimg.com/...        3285
# 8        1       NaN    NaN   NaN  http://pbs.twimg.com/...        3074
# 9        2       NaN    NaN   NaN  http://pbs.twimg.com/...        2745
# 10       0       NaN    NaN   NaN  http://pbs.twimg.com/...        4206
# 11       2       NaN    NaN   NaN  http://pbs.twimg.com/...         250
# 12       2       NaN    NaN   NaN  http://pbs.twimg.com/...         545
# 13       0       NaN    NaN   NaN  http://pbs.twimg.com/...        1333
# 14       1       NaN    NaN   NaN  http://pbs.twimg.com/...       13138
# 15       1       NaN    NaN   NaN  http://pbs.twimg.com/...        8117
# 16       1       NaN    NaN   NaN  http://pbs.twimg.com/...          10
# 17       1       NaN    NaN   NaN  http://pbs.twimg.com/...      228185
# 18       1       NaN    NaN   NaN  http://pbs.twimg.com/...          26
# 19       1       NaN    NaN   NaN  http://pbs.twimg.com/...          68
# 20       2       NaN    NaN   NaN  http://pbs.twimg.com/...          77
# 21       0       NaN    NaN   NaN  http://pbs.twimg.com/...       79189
# 22       1       NaN    NaN   NaN  http://pbs.twimg.com/...       24174
# 23       0       NaN    NaN   NaN  http://pbs.twimg.com/...        5400
# 24       1       NaN    NaN   NaN  http://pbs.twimg.com/...      979628
# 25       2       NaN    NaN   NaN  http://pbs.twimg.com/...         201
# 26       1       NaN    NaN   NaN  http://pbs.twimg.com/...         704
# 27       1       NaN    NaN   NaN  http://pbs.twimg.com/...        4089
# 28       0       NaN    NaN   NaN  http://pbs.twimg.com/...          77
# 29       1       NaN    NaN   NaN  http://pbs.twimg.com/...      820375
# 30       0       NaN    NaN   NaN  http://pbs.twimg.com/...         141
# 31       1       NaN    NaN   NaN  http://pbs.twimg.com/...       20605
# 32       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1332
# 33       1       NaN    NaN   NaN  http://pbs.twimg.com/...         904
# 34       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2234
# 35       0       NaN    NaN   NaN  http://pbs.twimg.com/...         788
# 36       2       NaN    NaN   NaN  http://pbs.twimg.com/...        3242
# 37       1       NaN    NaN   NaN  http://pbs.twimg.com/...         610
# 38       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2175
# 39       1       NaN    NaN   NaN  http://pbs.twimg.com/...         599
# 40       1       NaN    NaN   NaN  http://pbs.twimg.com/...         442
# 41       1       NaN    NaN   NaN  http://pbs.twimg.com/...       14868
# 42       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1948
# 43       1       NaN    NaN   NaN  http://pbs.twimg.com/...         136
# 44       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1101
# 45       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1540
# 46       1       NaN    NaN   NaN  http://pbs.twimg.com/...        6301
# 47       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1174
# 48       0       NaN    NaN   NaN  http://pbs.twimg.com/...       18732
# 49       0       NaN    NaN   NaN  http://pbs.twimg.com/...         401
#
#     nfriends            file_name                      path support2
# 0         20  B2r6ieiCQAAsrER.jpg  /media/alex/easystore...        1
# 1        528  B27wSReCMAA-MeD.jpg  /media/alex/easystore...        1
# 2       4126  B2fctmeCUAEiFZE.jpg  /media/alex/easystore...        1
# 3        580  B27fajnCUAERtfW.jpg  /media/alex/easystore...        1
# 4       2627  B2sKLtcCIAAkbYR.png  /media/alex/easystore...        1
# 5      45616  B2SJSCXIcAArA5_.png  /media/alex/easystore...        0
# 6       2889  B2QJjrfIAAAausK.jpg  /media/alex/easystore...        1
# 7        287  B3JL1XvIYAEPQmK.jpg  /media/alex/easystore...        1
# 8       2627  B27OX4fCAAAz0_1.png  /media/alex/easystore...        1
# 9        813  B21mjKNCMAAFP19.jpg  /media/alex/easystore...        1
# 10      4777  B3Ji5n1CQAAuAyP.jpg  /media/alex/easystore...        0
# 11       276  B1rURjTCYAAkZqu.jpg  /media/alex/easystore...        1
# 12        17  B3BFp6YIUAA53py.jpg  /media/alex/easystore...        1
# 13       721  B205eBjIUAMMpQ1.png  /media/alex/easystore...        0
# 14      1022  B176f4gIAAAQIhi.jpg  /media/alex/easystore...        1
# 15      1343  B27Js0lIYAISpzz.jpg  /media/alex/easystore...        1
# 16        43  B2SnycyCcAAAZfd.jpg  /media/alex/easystore...        1
# 17       962  B2qgLkaIEAAw6iE.jpg  /media/alex/easystore...        1
# 18        67  B3GP9KsCQAIdY_d.png  /media/alex/easystore...        1
# 19       217  B1yTJgmIEAA4dCa.jpg  /media/alex/easystore...        1
# 20       124  B2rKtWXCIAAr6LJ.jpg  /media/alex/easystore...        1
# 21     45617  B2v07A2IQAEmXPW.png  /media/alex/easystore...        0
# 22     18038  B3G5xsXCEAEkmtS.png  /media/alex/easystore...        1
# 23      5556  B0Ic-CVIMAAL_bD.jpg  /media/alex/easystore...        0
# 24       548  B3FCmIyCMAA8BBS.jpg  /media/alex/easystore...        1
# 25       482  B15DIJgCIAAAhy8.jpg  /media/alex/easystore...        1
# 26       984  B2LnipZIUAA5B6D.jpg  /media/alex/easystore...        1
# 27       121  B0rlfRyCEAA1AU1.jpg  /media/alex/easystore...        1
# 28       124  B2NwH9oCAAEI1AZ.jpg  /media/alex/easystore...        0
# 29       466  B22cPAuIMAEgdFl.png  /media/alex/easystore...        1
# 30       275  B2sfNKoCMAAComc.jpg  /media/alex/easystore...        0
# 31      2933  B1yisE7IIAAOlfg.jpg  /media/alex/easystore...        1
# 32       268  B1U45VkIYAAwxje.jpg  /media/alex/easystore...        1
# 33       625  B3E4s6UCAAAWY7D.jpg  /media/alex/easystore...        1
# 34      3566  B1jirl6IEAAKKy6.jpg  /media/alex/easystore...        1
# 35      2045  B2wy6f2IIAESaiy.png  /media/alex/easystore...        0
# 36        84  B2_sqPgCYAADx3j.jpg  /media/alex/easystore...        1
# 37       229  B2iYatAIYAAdMV8.jpg  /media/alex/easystore...        1
# 38      4437  B2SgnA_IMAIWUM6.jpg  /media/alex/easystore...        1
# 39       810  B250ZtFCQAA859Q.jpg  /media/alex/easystore...        1
# 40         0  BtPi5l0CcAAD_h7.jpg  /media/alex/easystore...        1
# 41         0  B14hyJnCAAESkrp.jpg  /media/alex/easystore...        1
# 42        79  B3FpSijIAAA6p6d.jpg  /media/alex/easystore...        1
# 43       215  B2MvacNCEAA1kAm.jpg  /media/alex/easystore...        1
# 44      1997  B3CO0OnIcAA8WQ9.jpg  /media/alex/easystore...        1
# 45      1384  B3JOsOmIMAAsdAb.jpg  /media/alex/easystore...        1
# 46       601  B3GAWoRIgAEhm8Q.jpg  /media/alex/easystore...        1
# 47      2740  Bv-VSo3IMAENjqV.jpg  /media/alex/easystore...        1
# 48     16573  B2pX6E5CcAAbnkJ.jpg  /media/alex/easystore...        0
# 49       151  B2raaBFCEAAej1x.png  /media/alex/easystore...        0

# %%
DATA.groupby('support2').count()
# Out:
#           tweet_id  date  text  support  hashtags  users  urls  media_urls  \
# support2
# 0              421   421   421      421         0      0     0         421
# 1             1578  1578  1579     1579         0      1     0        1579
#
#           nfollowers  nfriends  file_name  path
# support2
# 0                421       421        421   421
# 1               1579      1579       1579  1579

# %%
DATA = DATA.dropna(subset=['support2'])
len(DATA)
# Out:
# 2000

# %%
DATA.head()
# Out:
#              tweet_id                      date                      text  \
# 0  534514976191303680  Tue Nov 18 01:14:35 +...  Missouri Gov Declares...
# 1  535629606855143424  Fri Nov 21 03:03:44 +...  #Ferguson Lively prot...
# 2  533637761258250242  Sat Nov 15 15:08:51 +...  School board fires Te...
# 3  535611054089187329  Fri Nov 21 01:50:01 +...  This campaign was fun...
# 4  534532177803747328  Tue Nov 18 02:22:56 +...  WOW afraid of your fr...
#
#   support  hashtags  users  urls                media_urls  nfollowers  \
# 0       2       NaN    NaN   NaN  http://pbs.twimg.com/...          85
# 1       1       NaN    NaN   NaN  http://pbs.twimg.com/...         576
# 2       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2594
# 3       1       NaN    NaN   NaN  http://pbs.twimg.com/...        6599
# 4       1       NaN    NaN   NaN  http://pbs.twimg.com/...        3074
#
#    nfriends            file_name                      path support2
# 0        20  B2r6ieiCQAAsrER.jpg  /media/alex/easystore...        1
# 1       528  B27wSReCMAA-MeD.jpg  /media/alex/easystore...        1
# 2      4126  B2fctmeCUAEiFZE.jpg  /media/alex/easystore...        1
# 3       580  B27fajnCUAERtfW.jpg  /media/alex/easystore...        1
# 4      2627  B2sKLtcCIAAkbYR.png  /media/alex/easystore...        1

# %%
DATA['path'] = '/home/ajpineda/apsa_sample3/' + DATA['file_name'].astype(str)
DATA.head()
# Out:
#              tweet_id                      date                      text  \
# 0  534514976191303680  Tue Nov 18 01:14:35 +...  Missouri Gov Declares...
# 1  535629606855143424  Fri Nov 21 03:03:44 +...  #Ferguson Lively prot...
# 2  533637761258250242  Sat Nov 15 15:08:51 +...  School board fires Te...
# 3  535611054089187329  Fri Nov 21 01:50:01 +...  This campaign was fun...
# 4  534532177803747328  Tue Nov 18 02:22:56 +...  WOW afraid of your fr...
#
#   support  hashtags  users  urls                media_urls  nfollowers  \
# 0       2       NaN    NaN   NaN  http://pbs.twimg.com/...          85
# 1       1       NaN    NaN   NaN  http://pbs.twimg.com/...         576
# 2       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2594
# 3       1       NaN    NaN   NaN  http://pbs.twimg.com/...        6599
# 4       1       NaN    NaN   NaN  http://pbs.twimg.com/...        3074
#
#    nfriends            file_name                      path support2
# 0        20  B2r6ieiCQAAsrER.jpg  /home/ajpineda/apsa_s...        1
# 1       528  B27wSReCMAA-MeD.jpg  /home/ajpineda/apsa_s...        1
# 2      4126  B2fctmeCUAEiFZE.jpg  /home/ajpineda/apsa_s...        1
# 3       580  B27fajnCUAERtfW.jpg  /home/ajpineda/apsa_s...        1
# 4      2627  B2sKLtcCIAAkbYR.png  /home/ajpineda/apsa_s...        1

# %%
DATA = DATA[[os.path.isfile(i) for i in DATA['path']]]

# %%
#DATA = DATA[DATA.support != '2']
len(DATA)
# Out:
# 1941

# %%
remove_n = 41
drop_indices = np.random.choice(DATA.index, remove_n, replace=False)
DATA = DATA.drop(drop_indices)
len(DATA)
# Out:
# 1900

# %%
#Shuffle data

DATA = DATA.sample(frac=1, random_state=1234).reset_index(drop=True)
DATA.head()
# Out:
#              tweet_id                      date                      text  \
# 0  529365926848655362  Mon Nov 03 20:14:06 +...  From Michael Brown to...
# 1  532918918894350336  Thu Nov 13 15:32:26 +...  LIVE NOW: Michael Bro...
# 2  540319890083938304  Thu Dec 04 01:41:15 +...  The West Side Highway...
# 3  535241151075581952  Thu Nov 20 01:20:09 +...  These must be the #Ru...
# 4  540320314555498496  Thu Dec 04 01:42:56 +...  Why I Work: To be at ...
#
#   support  hashtags  users  urls                media_urls  nfollowers  \
# 0       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1378
# 1       2       NaN    NaN   NaN  http://pbs.twimg.com/...    14626239
# 2       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2533
# 3       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2154
# 4       1       NaN    NaN   NaN  http://pbs.twimg.com/...       71858
#
#    nfriends            file_name                      path support2
# 0      2073  B1ivgU8CIAET2to.jpg  /home/ajpineda/apsa_s...        1
# 1       539  B2VOlGjIEAAZAMU.jpg  /home/ajpineda/apsa_s...        1
# 2      1480  B3-aDL8CMAEfpUg.jpg  /home/ajpineda/apsa_s...        1
# 3       193  B22O-tOIAAANBrC.jpg  /home/ajpineda/apsa_s...        1
# 4      9698  B3-Z7ZACcAEyBhI.png  /home/ajpineda/apsa_s...        1

# %%
# Test data is set aside until parameter tuning is done

#test_data = DATA.sample(n=250, replace=False, weights=None, random_state=1234, axis=None)
#DATA = DATA.drop(test_data.index)
#len(test_data)

# %%
#test_data.groupby('support').count()

# %%
# Validation data used to check for overfitting

val_data = DATA.sample(n=250, replace=False, weights=None, random_state=1234, axis=None)
train_data = DATA.drop(val_data.index)
len(val_data)
# Out:
# 250

# %%
val_data.groupby('support2').count()
# Out:
#           tweet_id  date  text  support  hashtags  users  urls  media_urls  \
# support2
# 0               59    59    59       59         0      0     0          59
# 1              191   191   191      191         0      0     0         191
#
#           nfollowers  nfriends  file_name  path
# support2
# 0                 59        59         59    59
# 1                191       191        191   191

# %%
len(train_data)
#train_data.groupby('support').count()
# Out:
# 1650

# %%
train_data.head()
# Out:
#              tweet_id                      date                      text  \
# 0  529365926848655362  Mon Nov 03 20:14:06 +...  From Michael Brown to...
# 1  532918918894350336  Thu Nov 13 15:32:26 +...  LIVE NOW: Michael Bro...
# 2  540319890083938304  Thu Dec 04 01:41:15 +...  The West Side Highway...
# 3  535241151075581952  Thu Nov 20 01:20:09 +...  These must be the #Ru...
# 4  540320314555498496  Thu Dec 04 01:42:56 +...  Why I Work: To be at ...
#
#   support  hashtags  users  urls                media_urls  nfollowers  \
# 0       1       NaN    NaN   NaN  http://pbs.twimg.com/...        1378
# 1       2       NaN    NaN   NaN  http://pbs.twimg.com/...    14626239
# 2       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2533
# 3       1       NaN    NaN   NaN  http://pbs.twimg.com/...        2154
# 4       1       NaN    NaN   NaN  http://pbs.twimg.com/...       71858
#
#    nfriends            file_name                      path support2
# 0      2073  B1ivgU8CIAET2to.jpg  /home/ajpineda/apsa_s...        1
# 1       539  B2VOlGjIEAAZAMU.jpg  /home/ajpineda/apsa_s...        1
# 2      1480  B3-aDL8CMAEfpUg.jpg  /home/ajpineda/apsa_s...        1
# 3       193  B22O-tOIAAANBrC.jpg  /home/ajpineda/apsa_s...        1
# 4      9698  B3-Z7ZACcAEyBhI.png  /home/ajpineda/apsa_s...        1

# %%
#os.chdir('/media/alex/easystore/ids_monthly/BLM_images/apsa_sample3')

# %%
# re: generators with multiple inputs

#trainer_path = 'train/'
#im_size = 28
img_width, img_height = 256, 256
batch_size = 50

input_imgen = ImageDataGenerator(rescale = 1./255, 
                                   shear_range = 0.2, 
                                   zoom_range = 0.2,
                                   rotation_range=5.,
                                   horizontal_flip = True)


def text_generator(a,labs, n):
    while True:
         for i in range(a.shape[0] // n):
            d2 = a[n*i:n*(i+1)]
            y_text = labs[n*i:n*(i+1)]
            yield d2, y_text       
            
def multi_input_generator(df, x_image, y_image, x_txt, y_txt, b_size): 
    t1 = input_imgen.flow_from_dataframe(
        dataframe=df,
        directory = './apsa_sample3',
        x_col = x_image,
        y_col = y_image,
        target_size=(256, 256),
        batch_size=b_size,
        class_mode='categorical')
    
    t2 = text_generator(a=x_txt, labs = y_txt, n=b_size)
    
    while True:
        d1,y = t1.next()
        d1 = np.expand_dims(d1, axis = 0)
        d2, y_text = t2.__next__()
        yield [d2, d1[0]], [y_text, y]

# %%
##############################################################
###### TEXT PRE-PROCESSING ###############################


# PARAMETERS
#MAX_SEQUENCE_LENGTH = 30
# PARAMETERS
#MAX_SEQUENCE_LENGTH = 30
MAX_NUM_WORDS = 25
EMBEDDING_DIM = 100
#VALIDATION_SPLIT = 0.2


# SUBSET TO ONLY DATA AND LABELS
train_data_text = train_data[['text','support2']]
train_labels_text = train_data['support2'].values
train_data_text.head()

val_data_text = val_data[['text','support2']]
val_labels_text = val_data['support2'].values
val_data_text.head()
# Out:
#                           text support2
# 395   Even the kittens stan...        1
# 385   Flashback: Obama agre...        0
# 1549  Rest in peace mike br...        1
# 243   Rainy Sunday in #ferg...        1
# 1074  Local authorities fin...        1

# %%
len(val_labels_text)
# Out:
# 250

# %%
# tokenizers for training text data
tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, lower=True,split=' ')
tokenizer.fit_on_texts(train_data_text['text'].values)
sequences = tokenizer.texts_to_sequences(train_data_text['text'].values)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

train_data_text = pad_sequences(sequences)
train_labels_text = ku.to_categorical(np.asarray(train_labels_text))

print('Shape of train data tensor:', train_data_text.shape)
print('Shape of train label tensor:', train_labels_text.shape)


##########################################################################
# tokenizers for val text data


#tokenizer = Tokenizer(num_words=MAX_NUM_WORDS, lower=True,split=' ')
#tokenizer.fit_on_texts(val_data_text['text'].values)
val_sequences = tokenizer.texts_to_sequences(val_data_text['text'].values)

#word_index = tokenizer.word_index
#print('Found %s unique val tokens.' % len(word_index))

val_data_text = pad_sequences(val_sequences, maxlen=29)
val_labels_text = ku.to_categorical(np.asarray(val_labels_text))

#print('Shape of val data tensor:', val_data_text.shape)
#print('Shape of val label tensor:', val_labels_text.shape)
# Out:
# Found 6967 unique tokens.
# Shape of train data tensor: (1650, 15)
# Shape of train label tensor: (1650, 2)

# %%
print('Shape of val data tensor:', val_data_text.shape)
print('Shape of val label tensor:', val_labels_text.shape)
# Out:
# Shape of val data tensor: (250, 29)
# Shape of val label tensor: (250, 2)

# %% [markdown]
# # Scaling Text Data
#
# dat_sets = [train_data_text, val_data_text, test_data_text]
#
#
# def scale_mydata(X_train):
#
#     scaler = preprocessing.StandardScaler().fit(X_train)
#     scaler
#     # out: StandardScaler()
#
#     scaler.mean_
#
#     scaler.scale_
#
#
#     X_scaled = scaler.transform(X_train)
#     return X_scaled
#
#
# for dat in dat_sets:
#
#
#     scale_mydata(dat)

# %%
"""


train_generator = multi_input_generator(df = train_data, x_image='file_name', y_image='support',
                                    x_txt=train_data_text, y_txt=train_labels_text, b_size=batch_size)

val_generator = multi_input_generator(df = val_data, x_image='file_name', y_image='support',
                                    x_txt=val_data_text, y_txt=val_labels_text, b_size=batch_size)

test_generator = multi_input_generator(df = test_data, x_image='file_name', y_image='support',
                                    x_txt=test_data['text'], y_txt=test_data['support'], b_size=batch_size)
"""

# %%
trainsetsize = len(train_data)
print('Number of training observations: ' + str(trainsetsize))
# Out:
# Number of training observations: 1650

# %%
valsetsize = len(val_data)
print('Number of val observations: ' + str(valsetsize))
# Out:
# Number of val observations: 250

# %%
# Loading embeddings from Stanford NLP
# Good rundown of source code: https://blog.keras.io/using-pre-trained-word-embeddings-in-a-keras-model.html

# First, build index mapping words in the embeddings set
# to their embedding vector

# glove.twitter.27B.100d.txt
# glove.6B.100d.txt

print("Loading embeddings.")

embeddings_index = dict()
#texts = []
f = open('glove.6B.100d.txt', errors='ignore')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
#    texts.append(word)
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loading embeddings.
# Loaded 400000 word vectors.

# %%
list(embeddings_index.items())[15]
# Out:
# ('was',
#  array([ 1.3717e-01, -5.4287e-01,  1.9419e-01, -2.9953e-01,  1.7545e-01,
#          8.4672e-02,  6.7752e-01,  9.8295e-02, -3.5611e-02,  2.1334e-01,
#          5.1663e-01,  2.0687e-01,  4.4082e-01, -3.3655e-01,  5.6025e-01,
#         -6.8790e-01,  5.1957e-01, -2.1258e-01, -5.2708e-01, -1.2249e-01,
#          3.3099e-01,  2.6448e-02,  5.9007e-01,  6.5469e-03,  4.5405e-01,
#         -3.3884e-01, -2.8261e-01, -2.4633e-01,  1.0847e-01,  3.1640e-01,
#         -1.5368e-01,  7.3503e-01,  1.1858e-01,  7.0842e-01,  7.5081e-02,
#          2.9738e-01, -1.1395e-01,  4.0807e-01, -4.2531e-02, -2.1301e-01,
#         -7.9849e-01, -1.2703e-01,  7.5200e-01, -4.1746e-01,  4.6615e-01,
#         -3.9097e-02,  6.5961e-01, -3.2336e-01,  4.4200e-01, -9.4137e-01,
#         -2.3125e-01, -3.0604e-01,  7.9912e-01,  1.4581e+00, -8.8199e-01,
#         -3.0041e+00, -7.5243e-01, -2.0503e-01,  1.1998e+00,  9.4881e-01,
#          3.0649e-01,  4.8411e-01, -7.5720e-01,  6.5856e-01,  7.0107e-01,
#         -9.3141e-01,  5.2928e-01,  2.3323e-01,  1.8857e-01,  3.8691e-01,
#          1.1489e-02, -3.1937e-01,  1.1858e-02,  2.2944e-01,  1.7764e-01,
#          1.6868e-01,  1.4003e-01,  5.8647e-01, -1.5447e+00, -6.4425e-02,
#         -6.4711e-04,  1.3606e-01, -3.2695e-01,  1.0043e-01, -1.5460e+00,
#         -5.4760e-01,  2.1027e-01, -6.7195e-01, -1.5970e-01, -6.8271e-01,
#         -2.2043e-01, -8.7088e-01, -1.6248e-01,  8.3086e-01, -2.3045e-01,
#          1.9864e-01, -5.1892e-02, -5.2057e-01,  2.5434e-01, -2.3759e-01],
#        dtype=float32))

# %%
# At this point we can leverage our embedding_index dictionary and our word_index to compute our embedding matrix:


print('Preparing embedding matrix.')

# prepare embedding matrix
num_words = min(MAX_NUM_WORDS, len(word_index)) + 1
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if i > MAX_NUM_WORDS:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=MAX_NUM_WORDS,
                            trainable=False)
# Out:
# Preparing embedding matrix.

# %%
embeddings_index.get('blacklivesmatter')

# %%
#from tensorflow.keras.applications import inception_v3

# %%
###########################################################################
########## MODEL CONSTRUCTION #############################################



sequence_input = Input(shape=(None, ), dtype='int64')
embedded_sequences = embedding_layer(sequence_input)
x_text = Conv1D(32, kernel_size = 5, activation="relu", padding = 'same')(embedded_sequences)
x_text = MaxPooling1D(5)(x_text)
x_text = Conv1D(32, kernel_size = 5, activation="relu", padding = 'same')(x_text)
x_text = GlobalMaxPooling1D()(x_text)
#x_text = Dense(16, activation="relu")(x_text)
#x_text = Dropout(0.5)(x_text)
x = Dense(64, activation='relu')(x_text)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)
x = Dense(8, activation='relu')(x)
x = Dense(4, activation='relu')(x)
preds = Dense(2, activation='sigmoid')(x_text)


model = keras.Model(sequence_input, preds)
#model.summary()

tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=False)


print("Begin training...")

sgd = optimizers.SGD(lr=0.01, decay=1e-5, momentum=0.95, nesterov=True, clipvalue=.5)

model.compile(optimizer=sgd, loss="categorical_crossentropy", metrics = ['categorical_accuracy'])
# Out:
# Begin training...
# 2022-11-28 23:43:01.643522: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2022-11-28 23:43:01.643561: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-28 23:43:01.643574: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gl3198.arc-ts.umich.edu): /proc/driver/nvidia/version does not exist
# 2022-11-28 23:43:01.643807: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ajpineda/.local/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history = model.fit(train_data_text, train_labels_text, batch_size=50, epochs=50, validation_data=(val_data_text, val_labels_text))
# Out:
# Epoch 1/50
# 33/33 [==============================] - 2s 7ms/step - loss: 0.5209 - categorical_accuracy: 0.7836 - val_loss: 0.5521 - val_categorical_accuracy: 0.7640
# Epoch 2/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4848 - categorical_accuracy: 0.7873 - val_loss: 0.5522 - val_categorical_accuracy: 0.7600
# Epoch 3/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4590 - categorical_accuracy: 0.7903 - val_loss: 0.5503 - val_categorical_accuracy: 0.7600
# Epoch 4/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4483 - categorical_accuracy: 0.7952 - val_loss: 0.5429 - val_categorical_accuracy: 0.7560
# Epoch 5/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4396 - categorical_accuracy: 0.7994 - val_loss: 0.5569 - val_categorical_accuracy: 0.7560
# Epoch 6/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4218 - categorical_accuracy: 0.8139 - val_loss: 0.5628 - val_categorical_accuracy: 0.7680
# Epoch 7/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4124 - categorical_accuracy: 0.8152 - val_loss: 0.5668 - val_categorical_accuracy: 0.7640
# Epoch 8/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4061 - categorical_accuracy: 0.8109 - val_loss: 0.5745 - val_categorical_accuracy: 0.7640
# Epoch 9/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3923 - categorical_accuracy: 0.8267 - val_loss: 0.5990 - val_categorical_accuracy: 0.7600
# Epoch 10/50
# 33/33 [==============================] - 0s 8ms/step - loss: 0.3841 - categorical_accuracy: 0.8333 - val_loss: 0.5967 - val_categorical_accuracy: 0.7680
# Epoch 11/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3746 - categorical_accuracy: 0.8339 - val_loss: 0.6001 - val_categorical_accuracy: 0.7560
# Epoch 12/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3548 - categorical_accuracy: 0.8552 - val_loss: 0.6343 - val_categorical_accuracy: 0.7640
# Epoch 13/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3455 - categorical_accuracy: 0.8479 - val_loss: 0.6085 - val_categorical_accuracy: 0.7400
# Epoch 14/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3289 - categorical_accuracy: 0.8642 - val_loss: 0.6019 - val_categorical_accuracy: 0.7640
# Epoch 15/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3209 - categorical_accuracy: 0.8642 - val_loss: 0.6441 - val_categorical_accuracy: 0.7520
# Epoch 16/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3078 - categorical_accuracy: 0.8758 - val_loss: 0.6210 - val_categorical_accuracy: 0.7520
# Epoch 17/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3009 - categorical_accuracy: 0.8727 - val_loss: 0.6954 - val_categorical_accuracy: 0.7600
# Epoch 18/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3072 - categorical_accuracy: 0.8752 - val_loss: 0.6409 - val_categorical_accuracy: 0.7520
# Epoch 19/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2739 - categorical_accuracy: 0.8848 - val_loss: 0.7264 - val_categorical_accuracy: 0.7640
# Epoch 20/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2680 - categorical_accuracy: 0.8855 - val_loss: 0.6754 - val_categorical_accuracy: 0.7560
# Epoch 21/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2555 - categorical_accuracy: 0.8909 - val_loss: 0.6395 - val_categorical_accuracy: 0.7680
# Epoch 22/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2514 - categorical_accuracy: 0.8976 - val_loss: 0.6667 - val_categorical_accuracy: 0.7520
# Epoch 23/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2413 - categorical_accuracy: 0.8994 - val_loss: 0.7144 - val_categorical_accuracy: 0.7560
# Epoch 24/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2406 - categorical_accuracy: 0.9000 - val_loss: 0.6834 - val_categorical_accuracy: 0.7600
# Epoch 25/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2359 - categorical_accuracy: 0.9018 - val_loss: 0.7473 - val_categorical_accuracy: 0.7640
# Epoch 26/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2335 - categorical_accuracy: 0.9000 - val_loss: 0.6845 - val_categorical_accuracy: 0.7240
# Epoch 27/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2293 - categorical_accuracy: 0.9024 - val_loss: 0.7085 - val_categorical_accuracy: 0.7440
# Epoch 28/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2212 - categorical_accuracy: 0.9109 - val_loss: 0.6904 - val_categorical_accuracy: 0.7480
# Epoch 29/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2134 - categorical_accuracy: 0.9109 - val_loss: 0.8053 - val_categorical_accuracy: 0.7560
# Epoch 30/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2192 - categorical_accuracy: 0.9091 - val_loss: 0.7533 - val_categorical_accuracy: 0.7480
# Epoch 31/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2087 - categorical_accuracy: 0.9176 - val_loss: 0.8780 - val_categorical_accuracy: 0.7640
# Epoch 32/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2209 - categorical_accuracy: 0.9121 - val_loss: 0.7537 - val_categorical_accuracy: 0.7560
# Epoch 33/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2192 - categorical_accuracy: 0.9036 - val_loss: 0.7338 - val_categorical_accuracy: 0.7480
# Epoch 34/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2122 - categorical_accuracy: 0.9061 - val_loss: 0.7793 - val_categorical_accuracy: 0.7480
# Epoch 35/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2147 - categorical_accuracy: 0.9024 - val_loss: 0.7312 - val_categorical_accuracy: 0.7440
# Epoch 36/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2142 - categorical_accuracy: 0.9158 - val_loss: 0.7153 - val_categorical_accuracy: 0.7480
# Epoch 37/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2022 - categorical_accuracy: 0.9194 - val_loss: 0.7331 - val_categorical_accuracy: 0.7560
# Epoch 38/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1979 - categorical_accuracy: 0.9103 - val_loss: 0.8204 - val_categorical_accuracy: 0.7440
# Epoch 39/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2067 - categorical_accuracy: 0.9121 - val_loss: 0.7951 - val_categorical_accuracy: 0.7600
# Epoch 40/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2096 - categorical_accuracy: 0.9030 - val_loss: 0.9309 - val_categorical_accuracy: 0.7520
# Epoch 41/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2017 - categorical_accuracy: 0.9176 - val_loss: 0.8155 - val_categorical_accuracy: 0.7560
# Epoch 42/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1856 - categorical_accuracy: 0.9224 - val_loss: 0.7559 - val_categorical_accuracy: 0.7440
# Epoch 43/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2099 - categorical_accuracy: 0.9085 - val_loss: 0.7747 - val_categorical_accuracy: 0.7560
# Epoch 44/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1912 - categorical_accuracy: 0.9188 - val_loss: 0.9911 - val_categorical_accuracy: 0.7680
# Epoch 45/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1886 - categorical_accuracy: 0.9200 - val_loss: 0.8576 - val_categorical_accuracy: 0.7520
# Epoch 46/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1880 - categorical_accuracy: 0.9206 - val_loss: 0.8815 - val_categorical_accuracy: 0.7560
# Epoch 47/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1807 - categorical_accuracy: 0.9133 - val_loss: 0.9123 - val_categorical_accuracy: 0.7520
# Epoch 48/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1897 - categorical_accuracy: 0.9170 - val_loss: 0.7787 - val_categorical_accuracy: 0.7440
# Epoch 49/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1854 - categorical_accuracy: 0.9230 - val_loss: 0.8924 - val_categorical_accuracy: 0.7520
# Epoch 50/50
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1814 - categorical_accuracy: 0.9194 - val_loss: 0.7641 - val_categorical_accuracy: 0.7440

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')

#plt.savefig(train_file_name)
plt.show()

# %%
# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
print('\n# Generate predictions')
val_predictions = model.predict(val_data_text)
train_predictions = model.predict(train_data_text)
# Out:
# # Generate predictions
# 8/8 [==============================] - 0s 2ms/step
# 52/52 [==============================] - 0s 1ms/step

# %%
val_predictions2 = val_predictions.argmax(axis=1)
train_predictions2 = train_predictions.argmax(axis=1)
val_labels_text2 = val_labels_text.argmax(axis=1)
train_labels_text2 = train_labels_text.argmax(axis=1)

# %%
import itertools

# Grab true labels from the validation generator


# Generate confusion matrix

# labels = ['W', 'NW']
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html


conf_mat1 = confusion_matrix(val_labels_text2, val_predictions2, labels = [0, 1], sample_weight=None)
conf_mat2 = confusion_matrix(train_labels_text2, train_predictions2, labels = [0, 1], sample_weight=None)
#print(conf_mat)

# %%
plot_confusion_matrix(conf_mat1, classes=['Opposed', 'Support'],
                      title='Confusion matrix, with normalization', normalize = True)
# Out:
# Normalized confusion matrix
# [[0.08474576 0.91525424]
#  [0.05235602 0.94764398]]

# %%
plot_confusion_matrix(conf_mat2, classes=['Opposed', 'Support'],
                      title='Confusion matrix, with normalization', normalize = True)
# Out:
# Normalized confusion matrix
# [[0.78409091 0.21590909]
#  [0.03775039 0.96224961]]
